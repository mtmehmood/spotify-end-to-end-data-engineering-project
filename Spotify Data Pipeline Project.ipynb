# %% [markdown]
# # Spotify - Data Pipeline (ETL) using Python

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# This is used for Authntication
client_credentials_manager = SpotifyClientCredentials(client_id="a89b0554b9524effb3d2922e94a0e1ab", client_secret="162737169c6649f786ec07371632fde3")

# %%
# To extract data from the Spotify

# %%
# This is used for Authorization
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
sp

# %%
playlist_link = "https://open.spotify.com/playlist/4zzUm9eZmeb4t4nUCaNoo5"

# %%
playlist_link.split('/')[-1]
# Out:
# '4zzUm9eZmeb4t4nUCaNoo5'

# %%
#playlist_URI = playlist_link.split('/')[-1].split('?')[-1]

playlist_URI = playlist_link.split('/')[-1]
playlist_URI
# Out:
# '4zzUm9eZmeb4t4nUCaNoo5'

# %%
data =sp.playlist_tracks(playlist_URI)

# %%
len(data['items'])
# Out:
# 100

# %%
# Gives you the first element
data['items'][0]
# Out:
# {'added_at': '2025-05-15T13:51:39Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/kolibrimusic'},
#   'href': 'https://api.spotify.com/v1/users/kolibrimusic',
#   'id': 'kolibrimusic',
#   'type': 'user',
#   'uri': 'spotify:user:kolibrimusic'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
#Within the first element - extract 'track' and 'album' information
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
#Within the first element -  'Album id' information
data['items'][0]['track']['album']['id']
# Out:
# '1eCGY9WJpYgtaFh1Lk2KNo'

# %%
# Extract Album name 
data['items'][0]['track']['album']['name']
# Out:
# "You'll Be Alright, Kid (Chapter 1)"

# %%
# Extract Album release date 
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-09-26'

# %%
# Extract Album total tracks
data['items'][0]['track']['album']['total_tracks']
# Out:
# 11

# %%
# Extract Album External URLs
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'

# %%
#album_list = [] # Assigning a list
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify'] 
    album_element = {'album_id' : album_id, 'album_name' : album_name, 'album_release_date' : album_release_date,
                     'total_tracks' : album_total_tracks, 'url' : album_url}
    print(album_element)
#    album_list.append(album_element)
# Out:
# {'album_id': '1eCGY9WJpYgtaFh1Lk2KNo', 'album_name': "You'll Be Alright, Kid (Chapter 1)", 'album_release_date': '2024-09-26', 'total_tracks': 11, 'url': 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'}
# {'album_id': '0QLILSOq1IqAqx62drmv4E', 'album_name': 'back to friends', 'album_release_date': '2024-12-27', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/0QLILSOq1IqAqx62drmv4E'}
# {'album_id': '2MHUaRi9OCyTN02SoyRRBJ', 'album_name': 'MAYHEM', 'album_release_date': '2025-03-07', 'total_tracks': 14, 'url': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'}
# {'album_id': '6K0QR9UjPQysrOaaOLtWCZ', 'album_name': 'Lost the Girl', 'album_release_date': '2025-05-30', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/6K0QR9UjPQysrOaaOLtWCZ'}
# {'album_id': '7aJuG4TFXa2hmE4z1yxc3n', 'album_name': 'HIT ME HARD AND SOFT', 'album_release_date': '2024-05-17', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'}
# ...

# %%
album_list = [] # Assigning a list
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify'] 
    album_element = {'album_id' : album_id, 'album_name' : album_name, 'album_release_date' : album_release_date,
                     'total_tracks' : album_total_tracks, 'url' : album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '1eCGY9WJpYgtaFh1Lk2KNo',
#   'album_name': "You'll Be Alright, Kid (Chapter 1)",
#   'album_release_date': '2024-09-26',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'},
#  {'album_id': '0QLILSOq1IqAqx62drmv4E',
#   'album_name': 'back to friends',
#   'album_release_date': '2024-12-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0QLILSOq1IqAqx62drmv4E'},
#  {'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'album_name': 'MAYHEM',
#   'album_release_date': '2025-03-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'},
#  {'album_id': '6K0QR9UjPQysrOaaOLtWCZ',
#   'album_name': 'Lost the Girl',
#   'album_release_date': '2025-05-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6K0QR9UjPQysrOaaOLtWCZ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
# ...

# %%
# do it for the other elements

data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2025-05-15T13:51:39Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/kolibrimusic'},
#   'href': 'https://api.spotify.com/v1/users/kolibrimusic',
#   'id': 'kolibrimusic',
#   'type': 'user',
#   'uri': 'spotify:user:kolibrimusic'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
#This will give the lists of all the artists
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0fTSzq9jAh4c36UVb4V7CB'}, 'href': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB', 'id': '0fTSzq9jAh4c36UVb4V7CB', 'name': 'Alex Warren', 'type': 'artist', 'uri': 'spotify:artist:0fTSzq9jAh4c36UVb4V7CB'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'}, 'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S', 'id': '4G9NDjRyZFDlJKMRL8hx3S', 'name': 'sombr', 'type': 'artist', 'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}]
# ...

# %%
#This will give us the dictionary instead of the list
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0fTSzq9jAh4c36UVb4V7CB'}, 'href': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB', 'id': '0fTSzq9jAh4c36UVb4V7CB', 'name': 'Alex Warren', 'type': 'artist', 'uri': 'spotify:artist:0fTSzq9jAh4c36UVb4V7CB'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4G9NDjRyZFDlJKMRL8hx3S'}, 'href': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S', 'id': '4G9NDjRyZFDlJKMRL8hx3S', 'name': 'sombr', 'type': 'artist', 'uri': 'spotify:artist:4G9NDjRyZFDlJKMRL8hx3S'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}, 'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms', 'id': '1HY2Jd0NmPuamShAr6KMms', 'name': 'Lady Gaga', 'type': 'artist', 'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id' :artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'external_url': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '4G9NDjRyZFDlJKMRL8hx3S',
#   'artist_name': 'sombr',
#   'external_url': 'https://api.spotify.com/v1/artists/4G9NDjRyZFDlJKMRL8hx3S'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6dEATZHyG9UVDXp8iAD1aH',
#   'artist_name': 'Joanna',
#   'external_url': 'https://api.spotify.com/v1/artists/6dEATZHyG9UVDXp8iAD1aH'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '3sSkr4TQRtXMDOkjEQxHvb',
# ...

# %%
# We can do the same for Songs"
song_list = [] # Assigning a list
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id' :song_id, 'song_name' :song_name, 'duration_ms' :song_duration, 'url' :song_url,
                    'popularity':song_popularity, 'song_added':song_added, 'album_id' :album_id,
                    'artist_id':artist_id
                    }
                    
    song_list.append(song_element)

# %%
# Convert everything into proper dataFrame
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                          album_name  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo  You'll Be Alright, Kid (Chapter 1)
# 1  0QLILSOq1IqAqx62drmv4E                     back to friends
# 2  2MHUaRi9OCyTN02SoyRRBJ                              MAYHEM
# 3  6K0QR9UjPQysrOaaOLtWCZ                       Lost the Girl
# 4  7aJuG4TFXa2hmE4z1yxc3n                HIT ME HARD AND SOFT
#
#   album_release_date  total_tracks  \
# 0         2024-09-26            11
# 1         2024-12-27             1
# 2         2025-03-07            14
# 3         2025-05-30             1
# 4         2024-05-17            10
#
#                                                  url
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/0QLILSOq1IqAqx6...
# 2  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 3  https://open.spotify.com/album/6K0QR9UjPQysrOa...
# 4  https://open.spotify.com/album/7aJuG4TFXa2hmE4...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            100 non-null    object
#  1   album_name          100 non-null    object
#  2   album_release_date  100 non-null    object
#  3   total_tracks        100 non-null    int64
#  4   url                 100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id       artist_name  \
# 0    0fTSzq9jAh4c36UVb4V7CB       Alex Warren
# 1    4G9NDjRyZFDlJKMRL8hx3S             sombr
# 2    1HY2Jd0NmPuamShAr6KMms         Lady Gaga
# 3    0du5cEVh5yTK9QJze8zA0C        Bruno Mars
# 4    6dEATZHyG9UVDXp8iAD1aH            Joanna
# ..                      ...               ...
# 122  5vCn4cc4Ww3QutKZxfcmq3             CLYDE
# 123  7GlBOeep6PqTfFi59PTUUN     Chappell Roan
# 124  2NfEnoexAAiBUCrAE2X1kn  Marcus Lindeberg
# 125  1ey4vgagS6Gvn0Xjc0A20c    The Paddle Boy
# 126  5YGY8feqx7naU7z4HrwZM6       Miley Cyrus
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1    https://api.spotify.com/v1/artists/4G9NDjRyZFD...
# 2    https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3    https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4    https://api.spotify.com/v1/artists/6dEATZHyG9U...
# ..                                                 ...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary       186964
# 1  0FTmksd2dxiE5e3rWyJXs6     back to friends       199032
# 2  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile       251667
# 3  0xkgLMMo3IxIJTxk0w8chW       Lost the Girl       203898
# 4  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2RkZ5LkEzeHGRsm...          95
# 1  https://open.spotify.com/track/0FTmksd2dxiE5e3...          98
# 2  https://open.spotify.com/track/7so0lgd0zP2Sbgs...          91
# 3  https://open.spotify.com/track/0xkgLMMo3IxIJTx...          23
# 4  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         100
#
#              song_added                album_id               artist_id
# 0  2025-05-15T13:51:39Z  1eCGY9WJpYgtaFh1Lk2KNo  0fTSzq9jAh4c36UVb4V7CB
# 1  2025-06-05T13:52:34Z  0QLILSOq1IqAqx62drmv4E  4G9NDjRyZFDlJKMRL8hx3S
# ...

# %%
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB  Alex Warren
# 1  4G9NDjRyZFDlJKMRL8hx3S        sombr
# 2  1HY2Jd0NmPuamShAr6KMms    Lady Gaga
# 3  0du5cEVh5yTK9QJze8zA0C   Bruno Mars
# 4  6dEATZHyG9UVDXp8iAD1aH       Joanna
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1  https://api.spotify.com/v1/artists/4G9NDjRyZFD...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/6dEATZHyG9U...

# %%
album_df.head()
# Out:
#                  album_id                          album_name  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo  You'll Be Alright, Kid (Chapter 1)
# 1  0QLILSOq1IqAqx62drmv4E                     back to friends
# 2  2MHUaRi9OCyTN02SoyRRBJ                              MAYHEM
# 3  6K0QR9UjPQysrOaaOLtWCZ                       Lost the Girl
# 4  7aJuG4TFXa2hmE4z1yxc3n                HIT ME HARD AND SOFT
#
#   album_release_date  total_tracks  \
# 0         2024-09-26            11
# 1         2024-12-27             1
# 2         2025-03-07            14
# 3         2025-05-30             1
# 4         2024-05-17            10
#
#                                                  url
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/0QLILSOq1IqAqx6...
# 2  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 3  https://open.spotify.com/album/6K0QR9UjPQysrOa...
# 4  https://open.spotify.com/album/7aJuG4TFXa2hmE4...

# %%
#album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date']) - This gives the error so use the below code instead
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'], format='mixed', errors='coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            95 non-null     object
#  1   album_name          95 non-null     object
#  2   album_release_date  95 non-null     datetime64[ns]
#  3   total_tracks        95 non-null     int64
#  4   url                 95 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.5+ KB

# %%
#do the same for song added
song_df['song_added'] = pd.to_datetime(song_df['song_added'], format='mixed', errors='coerce')

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
